# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Saves only the non-null values in the data object

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x = data.drop(['median_house_value'],axis = 1)
y = data['median_house_value']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10429    -117.65     33.42                25.0       2174.0           428.0
# 20277    -119.22     34.18                17.0       3332.0           762.0
# 1510     -122.03     37.92                23.0       3318.0           408.0
# 15126    -116.84     32.86                16.0       2502.0           532.0
# 3567     -118.59     34.23                14.0       4407.0          1209.0
# ...          ...       ...                 ...          ...             ...
# 14351    -117.21     32.75                27.0       2072.0           534.0
# 1612     -122.08     37.87                26.0       2405.0           564.0
# 13942    -117.17     34.28                13.0       4867.0           718.0
# 13634    -117.34     34.08                33.0       4924.0          1007.0
# 1470     -121.98     37.95                16.0       2984.0           406.0
#
#        population  households  median_income ocean_proximity  \
# 10429       603.0       352.0         3.3967      NEAR OCEAN
# 20277      1797.0       673.0         4.4292      NEAR OCEAN
# 1510       1124.0       393.0         6.5847        NEAR BAY
# 15126      1211.0       494.0         3.2516       <1H OCEAN
# 3567       2676.0      1128.0         3.4091       <1H OCEAN
# ...           ...         ...            ...             ...
# 14351      1118.0       510.0         2.8043      NEAR OCEAN
# 1612        680.0       531.0         2.4896        NEAR BAY
# 13942       780.0       250.0         7.1997          INLAND
# 13634      3502.0       953.0         3.2330          INLAND
# 1470       1317.0       397.0         6.7821          INLAND
#
#        median_house_value
# 10429            249400.0
# 20277            231200.0
# 1510             358800.0
# 15126            202100.0
# 3567             168800.0
# ...                   ...
# 14351            262100.0
# 1612              73400.0
# 13942            253800.0
# 13634             99400.0
# 1470             265900.0
#
# [16346 rows x 10 columns]

# %% [markdown]
# Histogram

# %%
train_data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms']+1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms']+1)
train_data['population'] = np.log(train_data['population']+1)
train_data['households'] = np.log(train_data['households']+1)

# %%
train_data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7271
# INLAND        5152
# NEAR OCEAN    2078
# NEAR BAY      1841
# ISLAND           4
# Name: count, dtype: int64

# %% [markdown]
# Ocean Proximity is not a binary value. So we turn every value into a separate feature and give them true or false value

# %%
add_data = pd.get_dummies(train_data.ocean_proximity)
add_data = add_data.astype(int)

# %%
add_data
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 10429          0       0       0         0           1
# 20277          0       0       0         0           1
# 1510           0       0       0         1           0
# 15126          1       0       0         0           0
# 3567           1       0       0         0           0
# ...          ...     ...     ...       ...         ...
# 14351          0       0       0         0           1
# 1612           0       0       0         1           0
# 13942          0       1       0         0           0
# 13634          0       1       0         0           0
# 1470           0       1       0         0           0
#
# [16346 rows x 5 columns]

# %%
train_data=train_data.join(add_data).drop(['ocean_proximity'],axis = 1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10429    -117.65     33.42                25.0     7.684784        6.061457
# 20277    -119.22     34.18                17.0     8.111628        6.637258
# 1510     -122.03     37.92                23.0     8.107419        6.013715
# 15126    -116.84     32.86                16.0     7.825245        6.278521
# 3567     -118.59     34.23                14.0     8.391176        7.098376
# ...          ...       ...                 ...          ...             ...
# 14351    -117.21     32.75                27.0     7.636752        6.282267
# 1612     -122.08     37.87                26.0     7.785721        6.336826
# 13942    -117.17     34.28                13.0     8.490438        6.577861
# 13634    -117.34     34.08                33.0     8.502080        6.915723
# 1470     -121.98     37.95                16.0     8.001355        6.008813
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 10429    6.403574    5.866468         3.3967            249400.0          0
# 20277    7.494430    6.513230         4.4292            231200.0          0
# 1510     7.025538    5.976351         6.5847            358800.0          0
# 15126    7.100027    6.204558         3.2516            202100.0          1
# 3567     7.892452    7.029088         3.4091            168800.0          1
# ...           ...         ...            ...                 ...        ...
# 14351    7.020191    6.236370         2.8043            262100.0          0
# 1612     6.523562    6.276643         2.4896             73400.0          0
# 13942    6.660575    5.525453         7.1997            253800.0          0
# 13634    8.161375    6.860664         3.2330             99400.0          0
# 1470     7.183871    5.986452         6.7821            265900.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 10429       0       0         0           1
# 20277       0       0         0           1
# 1510        0       0         1           0
# 15126       0       0         0           0
# 3567        0       0         0           0
# ...       ...     ...       ...         ...
# 14351       0       0         0           1
# 1612        0       0         1           0
# 13942       1       0         0           0
# 13634       1       0         0           0
# 1470        1       0         0           0
#
# [16346 rows x 14 columns]

# %%
train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925197           -0.111114     0.027803
# latitude            -0.925197  1.000000            0.013762    -0.029053
# housing_median_age  -0.111114  0.013762            1.000000    -0.313548
# total_rooms          0.027803 -0.029053           -0.313548     1.000000
# total_bedrooms       0.058111 -0.064814           -0.270649     0.945331
# population           0.107825 -0.133260           -0.241806     0.863662
# households           0.052533 -0.083456           -0.241242     0.931684
# median_income       -0.011762 -0.080475           -0.122524     0.205625
# median_house_value  -0.041304 -0.146348            0.105128     0.157078
# <1H OCEAN            0.324758 -0.449633            0.048781     0.014602
# INLAND              -0.053394  0.348238           -0.240629    -0.006925
# ISLAND               0.009415 -0.016582            0.014109    -0.009675
# NEAR BAY            -0.477280  0.361468            0.253283    -0.015711
# NEAR OCEAN           0.042499 -0.157178            0.021792     0.003238
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.058111    0.107825    0.052533      -0.011762
# latitude                 -0.064814   -0.133260   -0.083456      -0.080475
# housing_median_age       -0.270649   -0.241806   -0.241242      -0.122524
# total_rooms               0.945331    0.863662    0.931684       0.205625
# total_bedrooms            1.000000    0.897101    0.975073      -0.028059
# population                0.897101    1.000000    0.930790      -0.007785
# households                0.975073    0.930790    1.000000       0.001175
# median_income            -0.028059   -0.007785    0.001175       1.000000
# median_house_value        0.052082   -0.026350    0.070342       0.685148
# <1H OCEAN                 0.037562    0.109954    0.067553       0.164293
# INLAND                   -0.041349   -0.066254   -0.082186      -0.230127
# ISLAND                   -0.003396   -0.013923   -0.009874      -0.010663
# NEAR BAY                 -0.014833   -0.058082   -0.004204       0.053402
# NEAR OCEAN                0.015869   -0.015852    0.018301       0.025681
#
#                     median_house_value  <1H OCEAN    INLAND    ISLAND  \
# longitude                    -0.041304   0.324758 -0.053394  0.009415
# latitude                     -0.146348  -0.449633  0.348238 -0.016582
# housing_median_age            0.105128   0.048781 -0.240629  0.014109
# total_rooms                   0.157078   0.014602 -0.006925 -0.009675
# total_bedrooms                0.052082   0.037562 -0.041349 -0.003396
# population                   -0.026350   0.109954 -0.066254 -0.013923
# households                    0.070342   0.067553 -0.082186 -0.009874
# median_income                 0.685148   0.164293 -0.230127 -0.010663
# median_house_value            1.000000   0.254503 -0.480911  0.026390
# <1H OCEAN                     0.254503   1.000000 -0.607252 -0.014004
# INLAND                       -0.480911  -0.607252  1.000000 -0.010614
# ISLAND                        0.026390  -0.014004 -0.010614  1.000000
# NEAR BAY                      0.158444  -0.318891 -0.241693 -0.005574
# NEAR OCEAN                    0.139439  -0.341598 -0.258903 -0.005971
#
#                     NEAR BAY  NEAR OCEAN
# longitude          -0.477280    0.042499
# latitude            0.361468   -0.157178
# housing_median_age  0.253283    0.021792
# total_rooms        -0.015711    0.003238
# total_bedrooms     -0.014833    0.015869
# population         -0.058082   -0.015852
# households         -0.004204    0.018301
# median_income       0.053402    0.025681
# median_house_value  0.158444    0.139439
# <1H OCEAN          -0.318891   -0.341598
# INLAND             -0.241693   -0.258903
# ISLAND             -0.005574   -0.005971
# NEAR BAY            1.000000   -0.135959
# NEAR OCEAN         -0.135959    1.000000

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x = "latitude", y = "longitude", data = train_data, hue = "median_house_value")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# Feature Engineering

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms']/train_data['total_rooms']

train_data['households_ratio'] = train_data['total_rooms']/train_data['households']

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

x_train, y_train = train_data.drop(['median_house_value'],axis = 1),train_data['median_house_value']

reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms']+1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms']+1)
test_data['population'] = np.log(test_data['population']+1)
test_data['households'] = np.log(test_data['households']+1)

add_data = pd.get_dummies(test_data.ocean_proximity)
add_data = add_data.astype(int)
test_data = test_data.join(add_data).drop(['ocean_proximity'], axis=1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['households_ratio'] = test_data['total_rooms'] / test_data['households']

# %%
x_test, y_test = test_data.drop(['median_house_value'],axis = 1),test_data['median_house_value']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16216    -121.32     37.95                36.0     6.617403        5.247024
# 9779     -121.13     36.21                30.0     7.303170        6.028279
# 1457     -121.97     37.97                26.0     7.589842        5.579730
# 8968     -118.40     33.99                36.0     7.155396        5.484797
# 17709    -121.82     37.33                23.0     8.095599        6.473891
# ...          ...       ...                 ...          ...             ...
# 9182     -118.56     34.37                23.0     8.275886        6.591674
# 6207     -117.90     34.06                33.0     7.439559        5.673323
# 13733    -117.19     34.05                33.0     7.431892        5.749393
# 4817     -118.29     34.04                48.0     7.210818        6.192362
# 19787    -122.95     40.67                17.0     7.312553        5.805135
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 16216    5.826000    4.983607         1.7885             62100.0          0
# 9779     7.090910    5.863631         1.7548             95800.0          1
# 1457     6.706862    5.613128         5.7512            240200.0          0
# 8968     6.558198    5.384495         5.9632            328100.0          1
# 17709    7.856707    6.447306         4.3782            175800.0          1
# ...           ...         ...            ...                 ...        ...
# 9182     7.593374    6.562444         4.8536            202600.0          1
# 6207     6.723832    5.620401         5.4469            274700.0          1
# 13733    6.695799    5.700444         3.2188            117800.0          0
# 4817     7.573531    6.190315         2.4359            123700.0          1
# 19787    6.354370    5.493061         2.0268             94200.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  households_ratio
# 16216       1       0         0           0       0.792913          1.327834
# 9779        0       0         0           0       0.825433          1.245503
# 1457        1       0         0           0       0.735158          1.352159
# 8968        0       0         0           0       0.766526          1.328889
# 17709       0       0         0           0       0.799680          1.255656
# ...       ...     ...       ...         ...            ...               ...
# 9182        0       0         0           0       0.796492          1.261098
# 6207        0       0         0           0       0.762589          1.323671
# 13733       1       0         0           0       0.773611          1.303739
# 4817        0       0         0           0       0.858760          1.164855
# 19787       1       0         0           0       0.793859          1.331235
#
# [4087 rows x 16 columns]

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10429    -117.65     33.42                25.0     7.684784        6.061457
# 20277    -119.22     34.18                17.0     8.111628        6.637258
# 1510     -122.03     37.92                23.0     8.107419        6.013715
# 15126    -116.84     32.86                16.0     7.825245        6.278521
# 3567     -118.59     34.23                14.0     8.391176        7.098376
# ...          ...       ...                 ...          ...             ...
# 14351    -117.21     32.75                27.0     7.636752        6.282267
# 1612     -122.08     37.87                26.0     7.785721        6.336826
# 13942    -117.17     34.28                13.0     8.490438        6.577861
# 13634    -117.34     34.08                33.0     8.502080        6.915723
# 1470     -121.98     37.95                16.0     8.001355        6.008813
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 10429    6.403574    5.866468         3.3967            249400.0          0
# 20277    7.494430    6.513230         4.4292            231200.0          0
# 1510     7.025538    5.976351         6.5847            358800.0          0
# 15126    7.100027    6.204558         3.2516            202100.0          1
# 3567     7.892452    7.029088         3.4091            168800.0          1
# ...           ...         ...            ...                 ...        ...
# 14351    7.020191    6.236370         2.8043            262100.0          0
# 1612     6.523562    6.276643         2.4896             73400.0          0
# 13942    6.660575    5.525453         7.1997            253800.0          0
# 13634    8.161375    6.860664         3.2330             99400.0          0
# 1470     7.183871    5.986452         6.7821            265900.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  households_ratio
# 10429       0       0         0           1       0.788761          1.309951
# 20277       0       0         0           1       0.818240          1.245408
# 1510        0       0         1           0       0.741755          1.356583
# 15126       0       0         0           0       0.802342          1.261209
# 3567        0       0         0           0       0.845933          1.193779
# ...       ...     ...       ...         ...            ...               ...
# 14351       0       0         0           1       0.822636          1.224551
# 1612        0       0         1           0       0.813904          1.240427
# 13942       1       0         0           0       0.774738          1.536605
# 13634       1       0         0           0       0.813416          1.239250
# 1470        1       0         0           0       0.750974          1.336577
#
# [16346 rows x 16 columns]

# %%
reg.score(x_test, y_test)
# Out:
# 0.6758780746582432
