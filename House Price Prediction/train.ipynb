# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Saves only the non-null values in the data object

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x = data.drop(['median_house_value'],axis = 1)
y = data['median_house_value']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13238    -117.67     34.13                10.0       2846.0           362.0
# 14733    -117.01     32.81                21.0       4203.0           618.0
# 865      -122.04     37.58                14.0      14917.0          2708.0
# 14907    -117.05     32.63                31.0       4911.0           861.0
# 18388    -121.89     37.23                20.0       7754.0           976.0
# ...          ...       ...                 ...          ...             ...
# 396      -122.29     37.89                52.0       3171.0           698.0
# 18505    -121.98     37.14                37.0         74.0            19.0
# 5526     -118.41     33.97                37.0       1629.0           275.0
# 15528    -117.08     33.12                43.0        107.0            44.0
# 1983     -120.76     38.65                17.0       2319.0           430.0
#
#        population  households  median_income ocean_proximity  \
# 13238      1221.0       355.0         7.7234          INLAND
# 14733      1620.0       600.0         5.3441       <1H OCEAN
# 865        8012.0      2606.0         5.6277        NEAR BAY
# 14907      2334.0       843.0         4.1958      NEAR OCEAN
# 18388      3094.0       941.0         8.1900       <1H OCEAN
# ...           ...         ...            ...             ...
# 396        1498.0       696.0         3.1795        NEAR BAY
# 18505        63.0        17.0         9.5908       <1H OCEAN
# 5526        668.0       266.0         6.1333       <1H OCEAN
# 15528       107.0        48.0         0.7054       <1H OCEAN
# 1983       1126.0       372.0         3.5511          INLAND
#
#        median_house_value
# 13238            304100.0
# 14733            193500.0
# 865              269800.0
# 14907            160100.0
# 18388            361600.0
# ...                   ...
# 396              218200.0
# 18505            350000.0
# 5526             387200.0
# 15528            137500.0
# 1983             155900.0
#
# [16346 rows x 10 columns]

# %% [markdown]
# Histogram

# %%
train_data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms']+1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms']+1)
train_data['population'] = np.log(train_data['population']+1)
train_data['households'] = np.log(train_data['households']+1)

# %%
train_data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7228
# INLAND        5230
# NEAR OCEAN    2081
# NEAR BAY      1804
# ISLAND           3
# Name: count, dtype: int64

# %% [markdown]
# Ocean Proximity is not a binary value. So we turn every value into a separate feature and give them true or false value

# %%
add_data = pd.get_dummies(train_data.ocean_proximity)
add_data = add_data.astype(int)

# %%
add_data
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 13238          0       1       0         0           0
# 14733          1       0       0         0           0
# 865            0       0       0         1           0
# 14907          0       0       0         0           1
# 18388          1       0       0         0           0
# ...          ...     ...     ...       ...         ...
# 396            0       0       0         1           0
# 18505          1       0       0         0           0
# 5526           1       0       0         0           0
# 15528          1       0       0         0           0
# 1983           0       1       0         0           0
#
# [16346 rows x 5 columns]

# %%
train_data=train_data.join(add_data).drop(['ocean_proximity'],axis = 1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13238    -117.67     34.13                10.0     7.954021        5.894403
# 14733    -117.01     32.81                21.0     8.343792        6.428105
# 865      -122.04     37.58                14.0     9.610324        7.904335
# 14907    -117.05     32.63                31.0     8.499436        6.759255
# 18388    -121.89     37.23                20.0     8.956093        6.884487
# ...          ...       ...                 ...          ...             ...
# 396      -122.29     37.89                52.0     8.062118        6.549651
# 18505    -121.98     37.14                37.0     4.317488        2.995732
# 5526     -118.41     33.97                37.0     7.396335        5.620401
# 15528    -117.08     33.12                43.0     4.682131        3.806662
# 1983     -120.76     38.65                17.0     7.749322        6.066108
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 
#                     NEAR BAY  NEAR OCEAN
# longitude          -0.473325    0.042454
# latitude            0.356901   -0.159242
# housing_median_age  0.254244    0.025977
# total_rooms        -0.022341    0.007761
# total_bedrooms     -0.020605    0.020368
# population         -0.062700   -0.010392
# households         -0.009698    0.023065
# median_income       0.053204    0.027825
# median_house_value  0.157007    0.144084
# <1H OCEAN          -0.313592   -0.340063
# INLAND             -0.241592   -0.261985
# ISLAND             -0.004772   -0.005175
# NEAR BAY            1.000000   -0.134526
# NEAR OCEAN         -0.134526    1.000000

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x = "latitude", y = "longitude", data = train_data, hue = "median_house_value")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# Feature Engineering

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms']/train_data['total_rooms']

train_data['households_ratio'] = train_data['total_rooms']/train_data['households']

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression

x_train, y_train = train_data.drop(['median_house_value'],axis = 1),train_data['median_house_value']

reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms']+1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms']+1)
test_data['population'] = np.log(test_data['population']+1)
test_data['households'] = np.log(test_data['households']+1)

add_data = pd.get_dummies(test_data.ocean_proximity)
add_data = add_data.astype(int)
test_data = test_data.join(add_data).drop(['ocean_proximity'], axis=1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['households_ratio'] = test_data['total_rooms'] / test_data['households']

# %%
x_test, y_test = test_data.drop(['median_house_value'],axis = 1),test_data['median_house_value']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15562    -116.97     33.13                10.0     8.546752        6.747587
# 8370     -118.34     33.98                40.0     7.653969        6.267201
# 11509    -118.10     33.74                33.0     7.659171        6.263398
# 6734     -118.10     34.12                49.0     8.238537        6.363028
# 17718    -121.77     37.33                 8.0     8.035603        6.163315
# ...          ...       ...                 ...          ...             ...
# 10823    -117.92     33.65                28.0     6.992096        6.049733
# 17843    -121.87     37.43                22.0     8.244334        6.391917
# 20488    -118.68     34.28                 5.0     8.724370        7.143618
# 5454     -118.46     34.00                36.0     7.239215        5.564520
# 10963    -117.88     33.77                31.0     7.843849        5.874931
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 15562    7.686162    6.664409         6.7957            287500.0          1
# 8370     7.561642    6.300786         3.1630            137800.0          1
# 11509    6.771936    6.144186         4.5370            495500.0          0
# 6734     7.379008    6.291569         6.3013            500001.0          1
# 17718    7.495542    6.124683         7.2707            355300.0          1
# ...           ...         ...            ...                 ...        ...
# 10823    6.694562    6.054439         0.9702            225400.0          1
# 17843    7.658700    6.432940         6.2892            254200.0          1
# 20488    8.067463    7.144407         4.7034            223000.0          1
# 5454     6.522093    5.513429         4.7344            346900.0          1
# 10963    6.951772    5.894403         6.9737            288800.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  households_ratio
# 15562       0       0         0           0       0.789491          1.282447
# 8370        0       0         0           0       0.818817          1.214764
# 11509       0       0         0           1       0.817764          1.246572
# 6734        0       0         0           0       0.772349          1.309457
# 17718       0       0         0           0       0.767001          1.312003
# ...       ...     ...       ...         ...            ...               ...
# 10823       0       0         0           0       0.865225          1.154871
# 17843       0       0         0           0       0.775310          1.281581
# 20488       0       0         0           0       0.818812          1.221147
# 5454        0       0         0           0       0.768664          1.313015
# 10963       0       0         0           0       0.748986          1.330728
#
# [4087 rows x 16 columns]

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13238    -117.67     34.13                10.0     7.954021        5.894403
# 14733    -117.01     32.81                21.0     8.343792        6.428105
# 865      -122.04     37.58                14.0     9.610324        7.904335
# 14907    -117.05     32.63                31.0     8.499436        6.759255
# 18388    -121.89     37.23                20.0     8.956093        6.884487
# ...          ...       ...                 ...          ...             ...
# 396      -122.29     37.89                52.0     8.062118        6.549651
# 18505    -121.98     37.14                37.0     4.317488        2.995732
# 5526     -118.41     33.97                37.0     7.396335        5.620401
# 15528    -117.08     33.12                43.0     4.682131        3.806662
# 1983     -120.76     38.65                17.0     7.749322        6.066108
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 13238    7.108244    5.874931         7.7234            304100.0          0
# 14733    7.390799    6.398595         5.3441            193500.0          1
# 865      8.988821    7.865955         5.6277            269800.0          0
# 14907    7.755767    6.738152         4.1958            160100.0          0
# 18388    8.037543    6.848005         8.1900            361600.0          1
# ...           ...         ...            ...                 ...        ...
# 396      7.312553    6.546785         3.1795            218200.0          0
# 18505    4.158883    2.890372         9.5908            350000.0          1
# 5526     6.505784    5.587249         6.1333            387200.0          1
# 15528    4.682131    3.891820         0.7054            137500.0          1
# 1983     7.027315    5.921578         3.5511            155900.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  households_ratio
# 13238       1       0         0           0       0.741059          1.353892
# 14733       0       0         0           0       0.770406          1.304004
# 865         0       0         1           0       0.822484          1.221762
# 14907       0       0         0           1       0.795259          1.261390
# 18388       0       0         0           0       0.768693          1.307840
# ...       ...     ...       ...         ...            ...               ...
# 396         0       0         1           0       0.812398          1.231462
# 18505       0       0         0           0       0.693860          1.493748
# 5526        0       0         0           0       0.759890          1.323788
# 15528       0       0         0           0       0.813019          1.203070
# 1983        1       0         0           0       0.782792          1.308658
#
# [16346 rows x 16 columns]

# %%
reg.score(x_test, y_test)
# Out:
# 0.6664673914137346

# %%
reg.coef_
# Out:
# array([ -29226.54554001,  -28204.73160087,    1080.84358354,
#         -80600.39344544,  134377.44145109,  -89675.98177417,
#          52419.57272767,   42419.83513388,  -22076.11404822,
#         -55306.1484597 ,  131172.22548452,  -31088.80843934,
#         -22701.15453727, -288740.31258736,    7559.59839224])

# %%
predictions = reg.predict(x_test)
actual = y_test

# %%
tolerance = 0.20
acceptable_range = tolerance * actual

# %%
within_range = np.abs(predictions - actual) <= acceptable_range

# %%
num_correct = np.sum(within_range)
total_predictions = len(predictions)

# %%
print(f"Number of correct predictions within tolerance: {num_correct}")
print(f"Total number of predictions: {total_predictions}")
percentage_correct = (num_correct / total_predictions) * 100
print(f"Percentage of correct predictions within tolerance: {percentage_correct:.2f}%")
# Out:
# Number of correct predictions within tolerance: 2047
# Total number of predictions: 4087
# Percentage of correct predictions within tolerance: 50.09%

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test, y_test)
# Out:
# 0.8111651036771441

# %%
from sklearn.model_selection import GridSearchCV
forest = RandomForestRegressor()

param_grid = {
    'n_estimators': [100,200,300],
    'min_samples_split': [2, 4],
    'max_depth': [None, 4, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           return_train_score=True) 
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_
best_forest
# Out:
# RandomForestRegressor(n_estimators=200)

# %%
best_forest.score(x_test, y_test)
# Out:
# 0.8122848329431311

# %%
predictions = best_forest.predict(x_test)
actual = y_test

# %%
tolerance = 0.20
acceptable_range = tolerance * actual

# %%
within_range = np.abs(predictions - actual) <= acceptable_range

# %%
num_correct = np.sum(within_range)
total_predictions = len(predictions)

# %%
print(f"Number of correct predictions within tolerance: {num_correct}")
print(f"Total number of predictions: {total_predictions}")
percentage_correct = (num_correct / total_predictions) * 100
print(f"Percentage of correct predictions within tolerance: {percentage_correct:.2f}%")
# Out:
# Number of correct predictions within tolerance: 2904
# Total number of predictions: 4087
# Percentage of correct predictions within tolerance: 71.05%
